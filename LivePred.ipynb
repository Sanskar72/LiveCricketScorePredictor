# %%
import pandas as pd
df = pd.read_csv('t20.csv')
X = df.iloc[:,[7,8,9,10,11,12,13]].values
y = df.iloc[:, 14].values
df.head(100)
#Features are CURRENT TOTAL RUNS, CURRENT WICKETS TAKEN, CURRENT OVER,
#RUNS IN LAST 5 OVERS, WICKETS IN LAST 5 OVERS, RUNS BY STRIKER, RUNS BY NON-STRIKER
# Out:
#     mid        date          venue bat_team  bowl_team         batsman  \
# 0     1  2005-06-13  The Rose Bowl  England  Australia  ME Trescothick
# 1     1  2005-06-13  The Rose Bowl  England  Australia  ME Trescothick
# 2     1  2005-06-13  The Rose Bowl  England  Australia        GO Jones
# 3     1  2005-06-13  The Rose Bowl  England  Australia        GO Jones
# 4     1  2005-06-13  The Rose Bowl  England  Australia        GO Jones
# ..  ...         ...            ...      ...        ...             ...
# 95    1  2005-06-13  The Rose Bowl  England  Australia  PD Collingwood
# 96    1  2005-06-13  The Rose Bowl  England  Australia      AJ Strauss
# 97    1  2005-06-13  The Rose Bowl  England  Australia      AJ Strauss
# 98    1  2005-06-13  The Rose Bowl  England  Australia  PD Collingwood
# 99    1  2005-06-13  The Rose Bowl  England  Australia  PD Collingwood
#
#        bowler  runs  wickets  overs  runs_last_5  wickets_last_5  striker  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators=100,max_features=None)
reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_features=None)

# %%
"""
import pickle

with open('LiveCricPred.pickle','wb') as f:
    pickle.dump(reg, f)
    
#TO USE THE PICKLE USE THE FOLLOWING CODE

pickle_in=open('LiveCricPred.pickle','rb')
reg=pickle.load(picke_in)
"""
# Out:
# "\nimport pickle\n\nwith open('LiveCricPred.pickle','wb') as f:\n    pickle.dump(reg, f)\n    \n#TO USE THE PICKLE USE THE FOLLOWING CODE\n\npickle_in=open('LiveCricPred.pickle','rb')\nreg=pickle.load(picke_in)\n"

# %%
from sklearn import metrics
import numpy as np

y_pred = reg.predict(X_test)
score = reg.score(X_test,y_test)*100
print("R square value:" , score)
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R square value: 66.2138044965128
# Root Mean Squared Error: 17.69823536461011

# %%
import numpy as np
new_prediction = reg.predict(sc.transform(np.array([[100,2,12,40,1,5,50]])))
print("Prediction score:" , int(new_prediction))
# Out:
# Prediction score: 175

# %%
team=np.random.randint(9)
venue=np.random.randint(9)

if team==venue:
    new_prediction+=10

# %%
pitch=np.random.randint(3)
toss=np.random.randint(2)

if pitch==1 and toss==1:
    new_prediction+=10
elif pitch==3 and toss==1:
    new_prediction-=10

# %%
print("Prediction score:" , int(new_prediction))
